# %% [markdown]
# ![16543028534TaslCLGyT.png](data:image/png;base64,...)

# %%
# !python --version
# Out:
# Python 3.10.11

# %% [markdown]
# **Variables**

# %%
a=100
b=20.3
c="Hello World"

# %%
type(b)
# Out:
# float

# %% [markdown]
# **Operators**

# %% [markdown]
# Arithmatic

# %%
a = 21
b = 10

# Addition
print ("a + b : ", a + b)

# Subtraction
print ("a - b : ", a - b)

# Multiplication
print ("a * b : ", a * b)

# Division
print ("a / b : ", a / b)

# Modulus
print ("a % b : ", a % b)

# Exponent
print ("a ** b : ", a ** b)

# Floor Division
print ("a // b : ", a // b)
# Out:
# a + b :  31
# a - b :  11
# a * b :  210
# a / b :  2.1
# a % b :  1
# a ** b :  16679880978201
# a // b :  2

# %% [markdown]
# Comparison Operator

# %%
a = 4
b = 5

# Equal
print ("a == b : ", a == b)

# Not Equal
print ("a != b : ", a != b)

# Greater Than
print ("a > b : ", a > b)

# Less Than
print ("a < b : ", a < b)

# Greater Than or Equal to
print ("a >= b : ", a >= b)

# Less Than or Equal to
print ("a <= b : ", a <= b)
# Out:
# a == b :  False
# a != b :  True
# a > b :  False
# a < b :  True
# a >= b :  False
# a <= b :  True

# %%
# Assignment Operator
a = 10

# Multiplication Assignment
a *= 5
print ("a *= 5 : ", a)

# Division Assignment
a /= 5
print ("a /= 5 : ",a)

# Remainder Assignment
a %= 3
print ("a %= 3 : ", a)

# Exponent Assignment
a **= 2
print ("a **= 2 : ", a)

# Floor Division Assignment
a //= 3
print ("a //= 3 : ", a)
# Out:
# a *= 5 :  50
# a /= 5 :  10.0
# a %= 3 :  1.0
# a **= 2 :  1.0
# a //= 3 :  0.0

# %%
# Logical operators (and, or, not)
a=True
b=False

not(a or b)
# Out:
# False

# %%
# Membership operators (in, not in)
a=[1,2,3,4]  #a list

print(2 in a)
print(3 not in a)
# Out:
# True
# False

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
print(2 in a)
# Out:
# True

# %% [markdown]
# **Decision Making**

# %%
b = 2
if b==2:
  print("Number is 2")
elif b==3:
  print("Number is 3")
else:
  print("Number is not 2/3")
# Out:
# Number is 2

# %%
a=11
if a>10:
  print("Greater than 10")
  print("Greater than 10")
elif a<10:
  print("Less than 10")
else:
  print("Equal to 10")
# Out:
# Greater than 10
# Greater than 10

# %%
a = 2;
if a%2==0:
  print("Even")
else:
  print("Odd")
# Out:
# Even

# %% [markdown]
# **Loop**

# %%
St = "abc"
for i in range(0,3):
  print(St[i])
# Out:
# a
# b
# c

# %%
print
printf("\n")

# %%
for i in "Hello World.":
  if i=='.':
    break
  elif i==' ':
    continue
  else:
    print(i,end = ' ')
# Out:
# H e l l o W o r l d

# %% [markdown]
# **List**

# %%
list1 = ['physics', 'chemistry', 1997, 2000]
list2 = [1, 2, 3, 4, 5 ]
list3 = ["a", "b", "c", "d"]

# %%
type(list1)
# Out:
# list

# %%
type(list1[3])
# Out:
# int

# %%
type(list1[1])
# Out:
# str

# %%
list1 = ['physics', 'chemistry', 1997, 2000]
list1.append(2003)
list1[2]=1900    #update
del list1[1]
list1
# Out:
# ['physics', 1900, 2000, 2003]

# %%
list2[1]
# Out:
# 2

# %%
list2 = [1, 2, 3, 4, 5 ]

# %%
# Slicing
list2[-5]
# Out:
# 1

# %%
for i in list1+list2:
  print(i)
# Out:
# physics
# 1900
# 2000
# 2003
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **Tuple**
#
#
# `
# The differences between tuples and lists are, the tuples cannot be changed unlike lists and tuples use parentheses, whereas lists use square brackets.
# `

# %%
tup1 = ('physics', 'chemistry', 1997, 2000);
tup2 = (1, 2, 3, 4, 5, 6, 7 );
print ("tup1[0]: ", tup1[0])
print ("tup2[1:5]: ", tup2[1:5])
# Out:
# tup1[0]:  physics
# tup2[1:5]:  (2, 3, 4, 5)

# %%
tup1[0]=200
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-e199d95c4de0> in <cell line: 1>()
# ----> 1 tup1[0]=200
#
# TypeError: 'tuple' object does not support item assignment

# %%
for i in tup1+tup2:
  print(i)
# Out:
# physics
# chemistry
# 1997
# 2000
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
tup1+tup2
# Out:
# ('physics', 'chemistry', 1997, 2000, 1, 2, 3, 4, 5, 6, 7)

# %%
print(tup1)
del tup1
# Out:
# ('physics', 'chemistry', 1997, 2000)

# %%
tup1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-afd04ff38ac4> in <cell line: 1>()
# ----> 1 tup1
#
# NameError: name 'tup1' is not defined

# %% [markdown]
# **Dictionary**
#
#
#
# ```
# # Key-Value pair
# ```
# `Keys are unique within a dictionary while values may not be. The values of a dictionary can be of any type, but the keys must be of an immutable data type such as strings, numbers, or tuples.`

# %%
dic = {'Name': 'Zara', 'Age': 7, 'Class': 'First',5:"Five"}
dic['Name']='Sara'
print (dic['Name'])
print(dic)
# Out:
# Sara
# {'Name': 'Sara', 'Age': 7, 'Class': 'First', 5: 'Five'}

# %%
dic['Class']
# Out:
# 'First'

# %%
dic[6]='Six'
dic
# Out:
# {'Name': 'Sara', 'Age': 7, 'Class': 'First', 5: 'Five', 6: 'Six'}

# %%
dic = {'Name': 'Zara', 'Age': 7, 'Class': 'First',5:"Five"}

# %%
del dic['Name']; # remove entry with key 'Name'
print(dic)
dic.clear();     # remove all entries in dict
print(dic)
#del dic ;        # delete entire dictionary
#print(dic)
# Out:
# {'Age': 7, 'Class': 'First', 5: 'Five'}
# {}

# %% [markdown]
# **Function**

# %%
a=10
def func(a):
  a=a*2
  print(a)
  return

# %%
# Reference is not maintained
func(a)
a
# Out:
# 20
# 10

# %%
b=[10]
def func(a):
  a.append(40)
  print(a)
  return

# %%
# Reference is maintained
func(b)
b
# Out:
# [10, 40]
# [10, 40]

# %%
for i in range(0,-10,-2):
  print(i)
# Out:
# 0
# -2
# -4
# -6
# -8
